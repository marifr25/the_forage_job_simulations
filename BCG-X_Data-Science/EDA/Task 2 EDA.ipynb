# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Data

# %%
client_df = pd.read_csv('client_data (1).csv')
price_df = pd.read_csv('price_data (1).csv')

# %%
client_df.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
price_df.head()
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %% [markdown]
# ## Preprocessing & Analyze Data

# %% [markdown]
# ### client_data.csv

# %%
client_df.shape
# Out:
# (14606, 26)

# %%
client_df[client_df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, channel_sales, cons_12m, cons_gas_12m, cons_last_month, date_activ, date_end, date_modif_prod, date_renewal, forecast_cons_12m, forecast_cons_year, forecast_discount_energy, forecast_meter_rent_12m, forecast_price_energy_off_peak, forecast_price_energy_peak, forecast_price_pow_off_peak, has_gas, imp_cons, margin_gross_pow_ele, margin_net_pow_ele, nb_prod_act, net_margin, num_years_antig, origin_up, pow_max, churn]
# Index: []
#
# [0 rows x 26 columns]

# %%
client_df.replace('MISSING', np.nan, inplace=True)

# %%
client_df.isna().any()
# Out:
# id                                False
# channel_sales                      True
# cons_12m                          False
# cons_gas_12m                      False
# cons_last_month                   False
# date_activ                        False
# date_end                          False
# date_modif_prod                   False
# date_renewal                      False
# forecast_cons_12m                 False
# forecast_cons_year                False
# forecast_discount_energy          False
# forecast_meter_rent_12m           False
# forecast_price_energy_off_peak    False
# forecast_price_energy_peak        False
# forecast_price_pow_off_peak       False
# has_gas                           False
# imp_cons                          False
# margin_gross_pow_ele              False
# margin_net_pow_ele                False
# nb_prod_act                       False
# net_margin                        False
# num_years_antig                   False
# ...

# %%
client_df.isna().sum()
# Out:
# id                                   0
# channel_sales                     3725
# cons_12m                             0
# cons_gas_12m                         0
# cons_last_month                      0
# date_activ                           0
# date_end                             0
# date_modif_prod                      0
# date_renewal                         0
# forecast_cons_12m                    0
# forecast_cons_year                   0
# forecast_discount_energy             0
# forecast_meter_rent_12m              0
# forecast_price_energy_off_peak       0
# forecast_price_energy_peak           0
# forecast_price_pow_off_peak          0
# has_gas                              0
# imp_cons                             0
# margin_gross_pow_ele                 0
# margin_net_pow_ele                   0
# nb_prod_act                          0
# net_margin                           0
# num_years_antig                      0
# origin_up                           64
# ...

# %%
client_df.dropna(inplace=True)

# %%
client_df.shape
# Out:
# (10831, 26)

# %%
client_df.columns
# Out:
# Index(['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'date_activ', 'date_end', 'date_modif_prod', 'date_renewal',
#        'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn'],
#       dtype='object')

# %% [markdown]
# The following is a description of each table:
# - id = client company identifier
# - activity_new = category of the company’s activity
# - channel_sales = code of the sales channel
# - cons_12m = electricity consumption of the past 12 months
# - cons_gas_12m = gas consumption of the past 12 months
# - cons_last_month = electricity consumption of the last month
# - date_activ = date of activation of the contract
# - date_end = registered date of the end of the contract
# - date_modif_prod = date of the last modification of the product
# - date_renewal = date of the next contract renewal
# - forecast_cons_12m = forecasted electricity consumption for next 12 months
# - forecast_cons_year = forecasted electricity consumption for the next calendar year
# - forecast_discount_energy = forecasted value of current discount
# - forecast_meter_rent_12m = forecasted bill of meter rental for the next 2 months
# - forecast_price_energy_off_peak = forecasted energy price for 1st period (off peak)
# - forecast_price_energy_peak = forecasted energy price for 2nd period (peak)
# - forecast_price_pow_off_peak = forecasted power price for 1st period (off peak)
# - has_gas = indicated if client is also a gas client
# - imp_cons = current paid consumption
# - margin_gross_pow_ele = gross margin on power subscription
# - margin_net_pow_ele = net margin on power subscription
# - nb_prod_act = number of active products and services
# - net_margin = total net margin
# - num_years_antig = antiquity of the client (in number of years)
# - origin_up = code of the electricity campaign the customer first subscribed to
# - pow_max = subscribed power
# - churn = has the client churned over the next 3 months

# %%
client_df.dtypes
# Out:
# id                                 object
# channel_sales                      object
# cons_12m                            int64
# cons_gas_12m                        int64
# cons_last_month                     int64
# date_activ                         object
# date_end                           object
# date_modif_prod                    object
# date_renewal                       object
# forecast_cons_12m                 float64
# forecast_cons_year                  int64
# forecast_discount_energy          float64
# forecast_meter_rent_12m           float64
# forecast_price_energy_off_peak    float64
# forecast_price_energy_peak        float64
# forecast_price_pow_off_peak       float64
# has_gas                            object
# imp_cons                          float64
# margin_gross_pow_ele              float64
# margin_net_pow_ele                float64
# nb_prod_act                         int64
# net_margin                        float64
# ...

# %%
date=["date_activ", "date_end", "date_modif_prod", "date_renewal"]

for i in date:
  client_df[i] = pd.to_datetime(client_df[i])

# %%
client_df.dtypes
# Out:
# id                                        object
# channel_sales                             object
# cons_12m                                   int64
# cons_gas_12m                               int64
# cons_last_month                            int64
# date_activ                        datetime64[ns]
# date_end                          datetime64[ns]
# date_modif_prod                   datetime64[ns]
# date_renewal                      datetime64[ns]
# forecast_cons_12m                        float64
# forecast_cons_year                         int64
# forecast_discount_energy                 float64
# forecast_meter_rent_12m                  float64
# forecast_price_energy_off_peak           float64
# forecast_price_energy_peak               float64
# forecast_price_pow_off_peak              float64
# has_gas                                   object
# imp_cons                                 float64
# margin_gross_pow_ele                     float64
# ...

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10831 entries, 0 to 14604
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10831 non-null  object
#  1   channel_sales                   10831 non-null  object
#  2   cons_12m                        10831 non-null  int64
#  3   cons_gas_12m                    10831 non-null  int64
#  4   cons_last_month                 10831 non-null  int64
#  5   date_activ                      10831 non-null  datetime64[ns]
#  6   date_end                        10831 non-null  datetime64[ns]
#  7   date_modif_prod                 10831 non-null  datetime64[ns]
#  8   date_renewal                    10831 non-null  datetime64[ns]
#  9   forecast_cons_12m               10831 non-null  float64
#  10  forecast_cons_year              10831 non-null  int64
# ...

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  \
# count  1.083100e+04  1.083100e+04     10831.000000
# mean   1.752256e+05  2.846208e+04     17506.815345
# min    0.000000e+00  0.000000e+00         0.000000
# 25%    5.893000e+03  0.000000e+00         0.000000
# 50%    1.496300e+04  0.000000e+00       847.000000
# 75%    4.420900e+04  0.000000e+00      3632.500000
# max    6.207104e+06  4.154590e+06    771203.000000
# std    6.129525e+05  1.702019e+05     68178.552846
#
#                           date_activ                       date_end  \
# count                          10831                          10831
# mean   2011-08-10 23:02:33.891607296  2016-07-22 18:35:19.915058432
# min              2005-02-25 00:00:00            2016-01-28 00:00:00
# 25%              2010-07-21 00:00:00            2016-04-24 00:00:00
# 50%              2011-11-17 00:00:00            2016-07-16 00:00:00
# 75%              2012-07-03 00:00:00            2016-10-24 00:00:00
# ...

# %%
client_df.select_dtypes(include=['number']).corr()
# Out:
#                                 cons_12m  cons_gas_12m  cons_last_month  \
# cons_12m                        1.000000      0.438931         0.968998
# cons_gas_12m                    0.438931      1.000000         0.458495
# cons_last_month                 0.968998      0.458495         1.000000
# forecast_cons_12m               0.196548      0.082117         0.179243
# forecast_cons_year              0.191618      0.090445         0.209465
# forecast_discount_energy       -0.049003     -0.009963        -0.045736
# forecast_meter_rent_12m         0.075042      0.049382         0.066087
# forecast_price_energy_off_peak -0.028200     -0.035941        -0.023965
# forecast_price_energy_peak      0.148992      0.070879         0.138974
# forecast_price_pow_off_peak    -0.055358     -0.040816        -0.050941
# imp_cons                        0.171889      0.081007         0.191558
# margin_gross_pow_ele           -0.028013      0.002201        -0.027737
# ...

# %% [markdown]
# ### price_data.csv

# %%
price_df.shape
# Out:
# (193002, 8)

# %%
price_df[price_df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, price_date, price_off_peak_var, price_peak_var, price_mid_peak_var, price_off_peak_fix, price_peak_fix, price_mid_peak_fix]
# Index: []

# %%
client_df.replace('MISSING', np.nan, inplace=True)

# %%
client_df.isna().any()
# Out:
# id                                False
# channel_sales                     False
# cons_12m                          False
# cons_gas_12m                      False
# cons_last_month                   False
# date_activ                        False
# date_end                          False
# date_modif_prod                   False
# date_renewal                      False
# forecast_cons_12m                 False
# forecast_cons_year                False
# forecast_discount_energy          False
# forecast_meter_rent_12m           False
# forecast_price_energy_off_peak    False
# forecast_price_energy_peak        False
# forecast_price_pow_off_peak       False
# has_gas                           False
# imp_cons                          False
# margin_gross_pow_ele              False
# margin_net_pow_ele                False
# nb_prod_act                       False
# net_margin                        False
# num_years_antig                   False
# ...

# %%
price_df.columns
# Out:
# Index(['id', 'price_date', 'price_off_peak_var', 'price_peak_var',
#        'price_mid_peak_var', 'price_off_peak_fix', 'price_peak_fix',
#        'price_mid_peak_fix'],
#       dtype='object')

# %% [markdown]
# The following is a description of each table:
# - id = client company identifier
# - price_date = reference date
# - price_off_peak_var = price of energy for the 1st period (off peak)
# - price_peak_var = price of energy for the 2nd period (peak)
# - price_mid_peak_var = price of energy for the 3rd period (mid peak)
# - price_off_peak_fix = price of power for the 1st period (off peak)
# - price_peak_fix = price of power for the 2nd period (peak)
# - price_mid_peak_fix = price of power for the 3rd period (mid peak)

# %%
price_df.dtypes
# Out:
# id                     object
# price_date             object
# price_off_peak_var    float64
# price_peak_var        float64
# price_mid_peak_var    float64
# price_off_peak_fix    float64
# price_peak_fix        float64
# price_mid_peak_fix    float64
# dtype: object

# %%
price_df["price_date"] = pd.to_datetime(price_df["price_date"])

# %%
price_df.dtypes
# Out:
# id                            object
# price_date            datetime64[ns]
# price_off_peak_var           float64
# price_peak_var               float64
# price_mid_peak_var           float64
# price_off_peak_fix           float64
# price_peak_fix               float64
# price_mid_peak_fix           float64
# dtype: object

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  datetime64[ns]
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 11.8+ MB

# %%
price_df.describe()
# Out:
#                           price_date  price_off_peak_var  price_peak_var  \
# count                         193002       193002.000000   193002.000000
# mean   2015-06-16 12:50:49.933161216            0.141027        0.054630
# min              2015-01-01 00:00:00            0.000000        0.000000
# 25%              2015-04-01 00:00:00            0.125976        0.000000
# 50%              2015-07-01 00:00:00            0.146033        0.085483
# 75%              2015-10-01 00:00:00            0.151635        0.101673
# max              2015-12-01 00:00:00            0.280700        0.229788
# std                              NaN            0.025032        0.049924
#
#        price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# count       193002.000000       193002.000000   193002.000000
# mean             0.030496           43.334477       10.622875
# min              0.000000            0.000000        0.000000
# ...

# %%
price_df.select_dtypes(include=['number']).corr()
# Out:
#                     price_off_peak_var  price_peak_var  price_mid_peak_var  \
# price_off_peak_var            1.000000       -0.328580           -0.594872
# price_peak_var               -0.328580        1.000000            0.821353
# price_mid_peak_var           -0.594872        0.821353            1.000000
# price_off_peak_fix            0.417097       -0.098627           -0.137848
# price_peak_fix               -0.630018        0.796097            0.973960
# price_mid_peak_fix           -0.572229        0.807759            0.979717
#
#                     price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# price_off_peak_var            0.417097       -0.630018           -0.572229
# price_peak_var               -0.098627        0.796097            0.807759
# price_mid_peak_var           -0.137848        0.973960            0.979717
# price_off_peak_fix            1.000000       -0.000428           -0.252661
# ...

# %% [markdown]
# ## Plotting Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %matplotlib inline

# %% [markdown]
# ### client_data.csv

# %% [markdown]
# ##### Overall Churn vs. Non-Churn Customers

# %%
churn_counts = client_df['churn'].value_counts()

# %%
plt.pie(churn_counts, labels=['Non-Churn', 'Churn'], autopct='%1.1f%%', startangle=140)
plt.title('Overall Churn vs. Non-Churn Customers')
plt.show()

# %% [markdown]
# ##### Churn Rate by `channel_sales`

# %%
# Create a mapping for channel_sales'
unique_channels = [channel for channel in client_df['channel_sales'].unique()]
channel_mapping = {channel: f'channel {i+1}' for i, channel in enumerate(unique_channels)}

# Apply the mapping
client_df['channel_sales_mapped'] = client_df['channel_sales'].map(channel_mapping)

# Calculate churn rate by mapped channel_sales
churn_rate = client_df.groupby('channel_sales_mapped')['churn'].mean().reset_index()

# %%
ax = sns.barplot(x='channel_sales_mapped', y='churn', data=churn_rate, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.title('Churn Rate by Sales Channel')
plt.xlabel('Sales Channel')
plt.ylabel('Churn Rate')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\582489085.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='channel_sales_mapped', y='churn', data=churn_rate, palette='viridis')

# %% [markdown]
# #### Churn Rate by Electricity Campaign

# %%
unique_campaign = [campaign for campaign in client_df['origin_up'].unique()]
campaign_mapping = {campaign: f'campaign {i+1}' for i, campaign in enumerate(unique_campaign)}
client_df['campaign_mapped'] = client_df['origin_up'].map(campaign_mapping)
campaign_churn_rate = client_df.groupby('campaign_mapped')['churn'].mean().reset_index()

# %%
ax = sns.barplot(x='campaign_mapped', y='churn', data=campaign_churn_rate, palette='viridis')
plt.title('Churn Rate by Electricity Campaign')
plt.xlabel('Electricity Campaign')
plt.ylabel('Churn Rate')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\3239734383.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='campaign_mapped', y='churn', data=campaign_churn_rate, palette='viridis')

# %% [markdown]
# #### Churn Rate which is a Gas Client too

# %%
client_df['has_gas'] = client_df['has_gas'].replace({'t': 'true', 'f': 'false'})
client_df['has_gas'] = client_df['has_gas'].astype('category')
gasclient_churnrate = client_df.groupby('has_gas')['churn'].mean().reset_index()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\293807825.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gasclient_churnrate = client_df.groupby('has_gas')['churn'].mean().reset_index()

# %%
ax = sns.barplot(x='has_gas', y='churn', data=gasclient_churnrate, palette='viridis')
plt.title('Churn Rate which is a Gas Client too')
plt.xlabel('Gas Client')
plt.ylabel('Churn Rate')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\2475475316.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='has_gas', y='churn', data=gasclient_churnrate, palette='viridis')

# %% [markdown]
# #### Client Churn Analysis of Consumption

# %%
# Renaming the values in 'churn', convert to category dtype column and create a new column
client_df['category_churn'] = client_df['churn'].replace({0:'non-churn', 
                                                          1: 'churn'}).astype('category')

# Grouping data by 'category_churn' and calculating mean consumption
grouped_consumption = client_df.groupby('category_churn')[['cons_12m', 
                                                           'cons_gas_12m', 
                                                           'cons_last_month']].mean().reset_index()

# Melting the data
consumption_melted = pd.melt(grouped_consumption, 
                             id_vars='category_churn', 
                             value_vars=['cons_12m', 'cons_gas_12m', 'cons_last_month'], 
                             var_name='Consumption Type', 
                             value_name='Average Consumption')

# Renaming the values in 'Consumption Type' column
consumption_melted['Consumption Type'] = consumption_melted['Consumption Type'].replace({'cons_12m': 'Electricity Consumption', 
                                                                                         'cons_gas_12m': 'Gas Consumption', 
                                                                                         'cons_last_month': 'Electricity Consumption Last Month'})
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\1250650223.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_consumption = client_df.groupby('category_churn')[['cons_12m',

# %%
# Plotting using Seaborn
ax = sns.barplot(x='category_churn', 
            y='Average Consumption', 
            hue='Consumption Type', 
            data=consumption_melted, 
            palette='viridis')

# Set labels and title
plt.xlabel('Category Churn')
plt.ylabel('Average Consumption')
plt.title('Client Churn Analysis of Consumption')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

# Add legend
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Show plot
plt.show()

# %% [markdown]
# #### Client Churn Analysis of Forecast

# %% [markdown]
# ##### Forecast Electricity Consumption

# %%
grouped_forecast = client_df.groupby('category_churn')[['forecast_cons_12m',
                                                        'forecast_cons_year']].mean().reset_index()

forecast_melted = pd.melt(grouped_forecast, 
                             id_vars='category_churn', 
                             value_vars=['forecast_cons_12m','forecast_cons_year'], 
                             var_name='Forecast Type', 
                             value_name='Average Forecast')

forecast_melted['Forecast Type'] = forecast_melted['Forecast Type'].replace({'forecast_cons_12m': 'Forecast Consumption',
                                                                             'forecast_cons_year': 'Forecast Consumption (Calendar)'})
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\1284311605.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_forecast = client_df.groupby('category_churn')[['forecast_cons_12m',

# %%
# Plotting using Seaborn
ax = sns.barplot(x='category_churn', 
                 y='Average Forecast', 
                 hue='Forecast Type', 
                 data=forecast_melted, 
                 palette='viridis')

# Set labels and title
plt.xlabel('Category Churn')
plt.ylabel('Average Forecast')
plt.title('Client Churn of Forecast Electricity Consumption')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

# Add legend
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Show plot
plt.show()

# %% [markdown]
# ##### Client Churn of `forecast_discount_energy`

# %%
grouped_discount = client_df.groupby('category_churn')[['forecast_discount_energy']].mean().reset_index()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\1970500672.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_discount = client_df.groupby('category_churn')[['forecast_discount_energy']].mean().reset_index()

# %%
ax = sns.barplot(x='category_churn', 
                 y='forecast_discount_energy',
                 data=grouped_discount, 
                 palette='viridis')

plt.xlabel('Category Churn')
plt.ylabel('Forecast Discount Energy')
plt.title('Client Churn of `forecast_discount_energy`')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\121303285.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='category_churn',

# %% [markdown]
# ##### Forecast Bill of Meter

# %%
grouped_meterbill = client_df.groupby('category_churn')[['forecast_meter_rent_12m']].mean().reset_index()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\346901921.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_meterbill = client_df.groupby('category_churn')[['forecast_meter_rent_12m']].mean().reset_index()

# %%
ax = sns.barplot(x='category_churn', 
                 y='forecast_meter_rent_12m',
                 data=grouped_meterbill, 
                 palette='viridis')

plt.xlabel('Category Churn')
plt.ylabel('Forecasted Bill of Meter Rental')
plt.title('Client Churn of Forecast Bill of Meter')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\4086867777.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='category_churn',

# %% [markdown]
# ##### Forecast Price Energy

# %%
price_energy = client_df.groupby('category_churn')[['forecast_price_energy_off_peak',
                                                    'forecast_price_energy_peak']].mean().reset_index()

price_energy_melted = pd.melt(price_energy, 
                             id_vars='category_churn', 
                             value_vars=['forecast_price_energy_off_peak',
                                         'forecast_price_energy_peak'], 
                             var_name='Forecast Type', 
                             value_name='Average Forecast')

price_energy_melted['Forecast Type'] = price_energy_melted['Forecast Type'].replace({'forecast_price_energy_off_peak': 'Energy Price Off Peak',
                                                                             'forecast_price_energy_peak': 'Energy Price Peak'})
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\4173053627.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_energy = client_df.groupby('category_churn')[['forecast_price_energy_off_peak',

# %%
# Plotting using Seaborn
ax = sns.barplot(x='category_churn', 
                 y='Average Forecast', 
                 hue='Forecast Type', 
                 data=price_energy_melted, 
                 palette='viridis')

# Set labels and title
plt.xlabel('Category Churn')
plt.ylabel('Energy Price')
plt.title('Forecast Price Energy')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

# Add legend
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Show plot
plt.show()

# %% [markdown]
# ##### Forecast Price Power

# %%
grouped_pricepower = client_df.groupby('category_churn')[['forecast_price_pow_off_peak']].mean().reset_index()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\4170464252.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_pricepower = client_df.groupby('category_churn')[['forecast_price_pow_off_peak']].mean().reset_index()

# %%
ax = sns.barplot(x='category_churn', 
                 y='forecast_price_pow_off_peak',
                 data=grouped_pricepower, 
                 palette='viridis')

plt.xlabel('Category Churn')
plt.ylabel('Power Price')
plt.title('Forecast Price Power')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\2681833659.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='category_churn',

# %% [markdown]
# #### Client Churn Analysis of Current Paid Consumption

# %%
grouped_paid = client_df.groupby('category_churn')[['imp_cons']].mean().reset_index()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\3966286012.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_paid = client_df.groupby('category_churn')[['imp_cons']].mean().reset_index()

# %%
ax = sns.barplot(x='category_churn', 
                 y='imp_cons',
                 data=grouped_paid, 
                 palette='viridis')

plt.xlabel('Category Churn')
plt.ylabel('Current Paid Consumption')
plt.title('Client Churn Analysis of Current Paid Consumption')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\2775802155.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='category_churn',

# %% [markdown]
# #### Client Churn Analysis of Margin

# %%
grouped_margin = client_df.groupby('category_churn')[['margin_gross_pow_ele',
                                                      'margin_net_pow_ele',
                                                      'net_margin']].mean().reset_index()

margin_melted = pd.melt(grouped_margin,
                        id_vars='category_churn',
                        value_vars=['margin_gross_pow_ele',
                                    'margin_net_pow_ele', 
                                    'net_margin'],
                        var_name='Margin Type',
                        value_name='Average Margin')

margin_melted['Margin Type'] = margin_melted['Margin Type'].replace({'margin_gross_pow_ele': 'Gross Margin (Power)',
                                                                     'margin_net_pow_ele': 'Net Margin (Power)', 
                                                                     'net_margin': 'Total Net Margin'})
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\501540399.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_margin = client_df.groupby('category_churn')[['margin_gross_pow_ele',

# %%
# Plotting using Seaborn
ax = sns.barplot(x='category_churn', 
                 y='Average Margin', 
                 hue='Margin Type', 
                 data=margin_melted, 
                 palette='viridis')

# Set labels and title
plt.xlabel('Category Churn')
plt.ylabel('Margin')
plt.title('Client Churn Analysis of Margin')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

# Add legend
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Show plot
plt.show()

# %% [markdown]
# #### Client Churn Analysis of Number of Active Products and Services

# %%
grouped_naps = client_df.groupby('category_churn')[['nb_prod_act']].mean().reset_index()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\4152679665.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_naps = client_df.groupby('category_churn')[['nb_prod_act']].mean().reset_index()

# %%
ax = sns.barplot(x='category_churn', 
                 y='nb_prod_act',
                 data=grouped_naps, 
                 palette='viridis')

plt.xlabel('Category Churn')
plt.ylabel('NAPS')
plt.title('Client Churn Analysis of Number of Active Products and Services')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\1688927882.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='category_churn',

# %% [markdown]
# #### Client Churn Analysis of The Client Antiquity

# %%
grouped_clients = client_df.groupby('category_churn')[['num_years_antig']].mean().reset_index()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\1277480286.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_clients = client_df.groupby('category_churn')[['num_years_antig']].mean().reset_index()

# %%
ax = sns.barplot(x='category_churn', 
                 y='num_years_antig',
                 data=grouped_clients, 
                 palette='viridis')

plt.xlabel('Category Churn')
plt.ylabel('Years')
plt.title('Client Churn Analysis of The Client Antiquity')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\2619580562.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='category_churn',

# %% [markdown]
# #### Client Churn Analysis of Subscribed Power

# %%
grouped_subscribed = client_df.groupby('category_churn')[['pow_max']].mean().reset_index()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\1110023318.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_subscribed = client_df.groupby('category_churn')[['pow_max']].mean().reset_index()

# %%
ax = sns.barplot(x='category_churn', 
                 y='pow_max',
                 data=grouped_subscribed, 
                 palette='viridis')

plt.xlabel('Category Churn')
plt.ylabel('Subscribed Power')
plt.title('Client Churn Analysis of Subscribed Power')
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)
for container in ax.containers:
    ax.bar_label(container)

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\3267162552.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='category_churn',

# %% [markdown]
# ### price_data.csv

# %% [markdown]
# #### Energy Price Range

# %%
energy_price = price_df[['price_off_peak_var', 'price_peak_var', 'price_mid_peak_var']]
labels = ['Off Peak', 'Peak', 'Mid Peak']

# %%
plt.boxplot(energy_price, labels=labels)
plt.xlabel('Price of Energy')
plt.ylabel('Price')
plt.title('Energy Price Range')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\3380774416.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(energy_price, labels=labels)

# %% [markdown]
# #### Power Price Range

# %%
power_price = price_df[['price_off_peak_fix', 'price_peak_fix', 'price_mid_peak_fix']]
labels = ['Off Peak', 'Peak', 'Mid Peak']

# %%
plt.boxplot(power_price, labels=labels)
plt.xlabel('Price of Power')
plt.ylabel('Price')
plt.title('Power Price Range')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11060\4159228342.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(power_price, labels=labels)
